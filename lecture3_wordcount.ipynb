# %% [markdown]
# <a href="https://colab.research.google.com/github/mervefilizbaker1/DSC-525-IS-Big-Data-Analytics/blob/main/lecture3_wordcount.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from pyspark import SparkContext #just for your reference
#sc = SparkContext("local", "WordCountApp")

from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("MyApp") \
    .getOrCreate()

sc = spark.sparkContext

# %%
text_file = sc.textFile("/path/to/your/textfile.txt")

counts = (text_file.flatMap(lambda line: line.split()).map(lambda word: (word, 1)).reduceByKey(lambda a, b: a + b))

# %%
for word, count in counts.collect():
  print(f"{word}: {count}")
