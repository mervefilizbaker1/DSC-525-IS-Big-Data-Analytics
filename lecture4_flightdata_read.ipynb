# %% [markdown]
# <a href="https://colab.research.google.com/github/mervefilizbaker1/DSC-525-IS-Big-Data-Analytics/blob/main/lecture4_flightdata_read.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/databricks/Spark-The-Definitive-Guide/refs/heads/master/data/flight-data/csv/2015-summary.csv
# Out:
# --2026-06-29 00:17:16--  https://raw.githubusercontent.com/databricks/Spark-The-Definitive-Guide/refs/heads/master/data/flight-data/csv/2015-summary.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7080 (6.9K) [text/plain]
# Saving to: ‘2015-summary.csv’
#
# 2015-summary.csv    100%[===================>]   6.91K  --.-KB/s    in 0s
#
# 2026-06-29 00:17:16 (70.0 MB/s) - ‘2015-summary.csv’ saved [7080/7080]

# %%
# !head /content/2015-summary.csv
# Out:
# DEST_COUNTRY_NAME,ORIGIN_COUNTRY_NAME,count
# United States,Romania,15
# United States,Croatia,1
# United States,Ireland,344
# Egypt,United States,15
# United States,India,62
# United States,Singapore,1
# United States,Grenada,62
# Costa Rica,United States,588
# Senegal,United States,40

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("flight").getOrCreate()
flightData2015 = spark.read.option("inferSchema", "true").option("header", "true").csv("/content/2015-summary.csv")

# %%
flightData2015.count()
# Out:
# 256

# %%
flightData2015.take(3)
# Out:
# [Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Romania', count=15),
#  Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Croatia', count=1),
#  Row(DEST_COUNTRY_NAME='United States', ORIGIN_COUNTRY_NAME='Ireland', count=344)]

# %%
flightData2015.createOrReplaceTempView("flight_data_2015")

# %% [markdown]
# SQL-way

# %%
sqlWay = spark.sql("""
SELECT DEST_COUNTRY_NAME, count(1)
FROM flight_data_2015
GROUP BY DEST_COUNTRY_NAME
""")

# %%
sqlWay.show(5)
# Out:
# +-----------------+--------+
# |DEST_COUNTRY_NAME|count(1)|
# +-----------------+--------+
# |         Anguilla|       1|
# |           Russia|       1|
# |         Paraguay|       1|
# |          Senegal|       1|
# |           Sweden|       1|
# +-----------------+--------+
# only showing top 5 rows

# %% [markdown]
# Dataframe way

# %%
dataFrameWay = flightData2015\
  .groupBy("DEST_COUNTRY_NAME")\
  .count()

# %%
dataFrameWay.show(5)
# Out:
# +-----------------+-----+
# |DEST_COUNTRY_NAME|count|
# +-----------------+-----+
# |         Anguilla|    1|
# |           Russia|    1|
# |         Paraguay|    1|
# |          Senegal|    1|
# |           Sweden|    1|
# +-----------------+-----+
# only showing top 5 rows

# %%
sqlWay.explain()
dataFrameWay.explain()
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- HashAggregate(keys=[DEST_COUNTRY_NAME#17], functions=[count(1)])
#    +- Exchange hashpartitioning(DEST_COUNTRY_NAME#17, 200), ENSURE_REQUIREMENTS, [plan_id=162]
#       +- HashAggregate(keys=[DEST_COUNTRY_NAME#17], functions=[partial_count(1)])
#          +- FileScan csv [DEST_COUNTRY_NAME#17] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/2015-summary.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<DEST_COUNTRY_NAME:string>
#
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- HashAggregate(keys=[DEST_COUNTRY_NAME#17], functions=[count(1)])
#    +- Exchange hashpartitioning(DEST_COUNTRY_NAME#17, 200), ENSURE_REQUIREMENTS, [plan_id=175]
#       +- HashAggregate(keys=[DEST_COUNTRY_NAME#17], functions=[partial_count(1)])
#          +- FileScan csv [DEST_COUNTRY_NAME#17] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/2015-summary.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<DEST_COUNTRY_NAME:string>

# %%
from pyspark.sql.functions import max

flightData2015.select(max("count")).take(1)

maxSql = spark.sql("""
SELECT DEST_COUNTRY_NAME, sum(count) as destination_total
FROM flight_data_2015
GROUP BY DEST_COUNTRY_NAME
ORDER BY sum(count) DESC
LIMIT 5
""")

maxSql.show()
# Out:
# +-----------------+-----------------+
# |DEST_COUNTRY_NAME|destination_total|
# +-----------------+-----------------+
# |    United States|           411352|
# |           Canada|             8399|
# |           Mexico|             7140|
# |   United Kingdom|             2025|
# |            Japan|             1548|
# +-----------------+-----------------+

# %%
from pyspark.sql.functions import desc

flightData2015\
  .groupBy("DEST_COUNTRY_NAME")\
  .sum("count")\
  .withColumnRenamed("sum(count)", "destination_total")\
  .sort(desc("destination_total"))\
  .limit(5)\
  .show()
# Out:
# +-----------------+-----------------+
# |DEST_COUNTRY_NAME|destination_total|
# +-----------------+-----------------+
# |    United States|           411352|
# |           Canada|             8399|
# |           Mexico|             7140|
# |   United Kingdom|             2025|
# |            Japan|             1548|
# +-----------------+-----------------+

# %%
flightData2015\
  .groupBy("DEST_COUNTRY_NAME")\
  .sum("count")\
  .withColumnRenamed("sum(count)", "destination_total")\
  .sort(desc("destination_total"))\
  .limit(5)\
  .explain()
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- TakeOrderedAndProject(limit=5, orderBy=[destination_total#105L DESC NULLS LAST], output=[DEST_COUNTRY_NAME#17,destination_total#105L])
#    +- HashAggregate(keys=[DEST_COUNTRY_NAME#17], functions=[sum(count#19)])
#       +- Exchange hashpartitioning(DEST_COUNTRY_NAME#17, 200), ENSURE_REQUIREMENTS, [plan_id=316]
#          +- HashAggregate(keys=[DEST_COUNTRY_NAME#17], functions=[partial_sum(count#19)])
#             +- FileScan csv [DEST_COUNTRY_NAME#17,count#19] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/content/2015-summary.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<DEST_COUNTRY_NAME:string,count:int>

# %% [markdown]
# Can you follow the previouse examples to retrieve the count of males and females who are greater than 15 years old? ou can have the data here: https://drive.google.com/drive/folders/1ehWwunuAo7CE1Vk2JYkUnQMmxh5pph3C

# %%
spark = SparkSession.builder.appName("titanic").getOrCreate()
titanic = spark.read.option("inferSchema", "true").option("header", "true").csv("/content/titanic.csv")

# %%
titanic.createOrReplaceTempView("titanic")
sqlWay = spark.sql("""
SELECT Sex, COUNT(*) AS passenger_count
FROM titanic
GROUP BY Sex
""")

sqlWay.show()
# Out:
# +------+---------------+
# |   Sex|passenger_count|
# +------+---------------+
# |female|            314|
# |  male|            577|
# +------+---------------+

# %%
#just an example with dataframe feature and groupby
titanic.groupBy("Pclass").count().show()
# Out:
# +------+-----+
# |Pclass|count|
# +------+-----+
# |     3|  469|
# |     1|  201|
# |     ?|   49|
# |     2|  172|
# +------+-----+
